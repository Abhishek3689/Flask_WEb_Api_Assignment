# %% [markdown]
# Q1. Explain GET and POST methods.

# %%
## GET:Sends data in unencrypted form to the server. Most common method.This data is visible to all

# %%
## Used to send HTML form data to server. Data received by POST method is not cached by server. It is secured as data entered is not visible to anybody

# %% [markdown]
# Q2. Why is request used in Flask?

# %%
## The Request, in Flask, is an object that contains all the data sent from the Client to Server. This data can be recovered using the GET/POST Methods

# %% [markdown]
# Q3. Why is redirect() used in Flask?

# %%
## Flask class has a redirect() function. When called, it returns a response object and redirects the user to another target location with specified status code.

# %% [markdown]
# Q4. What are templates in Flask? Why is the render_template() function used?

# %%
## Templates are files that contain static data as well as placeholders for dynamic data. 
## A template is rendered with specific data to produce a final document. Flask uses the Jinja template library to render templates

# %%
## render_template is a Flask function from the flask
## render_template is used to generate output from a template file based on the Jinja2 engine that is found in the application's templates folder

# %% [markdown]
# Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# %%
## I have copied code from flask

# %%
from flask import Flask,render_template,request,jsonify

app = Flask(__name__)

@app.route("/")
def hello_world():
    return render_template('index.html')

@app.route("/math",methods=['GET','POST'])
def math_calculation():
    if request.method=='POST':
        ops=request.form['operation']
        num1=int(request.form['num1'])
        num2=int(request.form['num2'])

        if ops=='Add':
            result=num1+num2
        if ops=='Multiply':
            result=num1*num2
        if ops=='Division':
            result=num1/num2

    return render_template('results.html',result=result)

@app.route("/postman_check",methods=['GET','POST'])
def math_calculation1():
    if request.method=='POST':
        ops=request.json['operation']
        num1=int(request.json['num1'])
        num2=int(request.json['num2'])

        if ops=='Add':
            result=num1+num2
        if ops=='Multiply':
            result=num1*num2
        if ops=='Division':
            result=num1/num2
    return jsonify(result)

if __name__=="__main__":
    app.run(host="0.0.0.0",port=8080)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from flask import Flask,render_template,request,jsonify
#       3 app = Flask(__name__)
#       5 @app.route("/")
#       6 def hello_world():
#
# ModuleNotFoundError: No module named 'flask'

# %% [markdown]
# ![image.png](attachment:410fc3ab-7d62-484b-b9be-ebc28bc50c62.png)

# %% [markdown]
# ![image.png](attachment:23dc794f-b9cd-4eb5-b188-f8a6ae5288a1.png)

# %% [markdown]
# ![image.png](attachment:35b56a0e-c5c3-4036-aee1-d372419c732a.png)
